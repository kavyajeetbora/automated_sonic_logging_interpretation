# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error as MAE
import plotly.graph_objects as go

# %%
df1 = pd.read_csv("B3_FWS-8200_2021-05-17_1715_NoAgc_Manually-TravelTime-P1-P2-P3.csv", sep=';')
df1.columns = df1.columns.str.strip()
df1
# Out:
#       Depth  ArrivalTime1_Manual  ArrivalTime2_Manual  ArrivalTime3_Manual
# 0      3.70              228.235              245.176              269.176
# 1      3.72              227.294              241.176              266.824
# 2      3.74              221.882              236.471              264.941
# 3      3.76              223.765              242.588              270.824
# 4      3.78              226.824              248.471              276.941
# ...     ...                  ...                  ...                  ...
# 1745  38.60              288.706              308.000              324.941
# 1746  38.62              287.529              304.941              324.941
# 1747  38.64              288.000              301.647              324.941
# 1748  38.66              286.588              298.824              324.941
# 1749  38.68              285.176              297.412              323.765
#
# [1750 rows x 4 columns]

# %% [markdown]
# Around 78 first arrival time values in the given file were negative:

# %%
dfx = df1[df1["ArrivalTime1_Manual"]<0].copy()
dfx
# Out:
#      Depth  ArrivalTime1_Manual  ArrivalTime2_Manual  ArrivalTime3_Manual
# 328  10.26               -999.0              228.235              245.176
# 329  10.28               -999.0              228.706              245.176
# 330  10.30               -999.0              230.588              244.706
# 337  10.44               -999.0              278.353              295.294
# 338  10.46               -999.0              288.000              301.647
# ..     ...                  ...                  ...                  ...
# 785  19.40               -999.0              372.706              387.765
# 817  20.04               -999.0              333.647              343.765
# 818  20.06               -999.0              329.647              340.235
# 819  20.08               -999.0              327.765              339.765
# 820  20.10               -999.0              319.529              340.235
#
# [78 rows x 4 columns]

# %%
df2 = df1[df1["ArrivalTime1_Manual"]>0].copy()
print(df2.shape)
df2.sample(5)
# Out:
# (1672, 4)
#       Depth  ArrivalTime1_Manual  ArrivalTime2_Manual  ArrivalTime3_Manual
# 20     4.10              232.000              248.000              274.118
# 1522  34.14              370.824              389.176              411.765
# 716   18.02              317.176              341.176              363.529
# 336   10.42              264.000              275.529              288.000
# 1385  31.40              360.000              380.471              402.118

# %%
df3 = pd.read_excel("600mm.xlsx",engine='openpyxl')
# df3 = 
df3
# Out:
#       Unnamed: 0  Depth  ArrivalTime1(µs)  Amplitude1(float)  \
# 0              0   3.70               224               1121
# 1              1   3.72               224                592
# 2              2   3.74               220                485
# 3              3   3.76               228                296
# 4              4   3.78               228                721
# ...          ...    ...               ...                ...
# 1745        1745  38.60               284               1257
# 1746        1746  38.62               284               1472
# 1747        1747  38.64               280               1398
# 1748        1748  38.66               280               1384
# 1749        1749  38.68               276               1024
#
#       ArrivalTime2(µs)  Amplitude2(float)  ArrivalTime3(µs)  Amplitude3(float)
# 0                  244              -3386               268               7693
# 1                  240              -2001               264               4924
# 2                  240              -1824               264               3877
# 3                  244              -1486               268               4439
# 4                  248              -1806               276               6577
# ...                ...                ...               ...                ...
# 1745               304              -9362               328              28890
# 1746               304             -10271               328              28598
# 1747               300             -10506               324              27115
# 1748               300              -9354               320              25207
# 1749               296              -7597               320              20412
#
# [1750 rows x 8 columns]

# %% [markdown]
# ## Evaluation of the results

# %%
eval_df = df3.merge(df2,on="Depth")
eval_df.sample(5)
# Out:
#      Unnamed: 0  Depth  ArrivalTime1(µs)  Amplitude1(float)  ArrivalTime2(µs)  \
# 592         665  17.00               332                463               368
# 228         228   8.26               220                337               248
# 466         514  13.98               284               1032               304
# 227         227   8.24               224                869               252
# 279         279   9.28               220                390               244
#
#      Amplitude2(float)  ArrivalTime3(µs)  Amplitude3(float)  \
# 592              -6533               392              32767
# 228              -2061               276               6401
# 466              -9832               328              31091
# 227              -4200               272              10351
# 279              -2177               268               7474
#
#      ArrivalTime1_Manual  ArrivalTime2_Manual  ArrivalTime3_Manual
# 592              332.000              365.882              388.706
# 228              223.294              233.971              263.529
# 466              284.706              304.000              335.059
# 227              225.412              238.382              269.176
# 279              221.412              242.588              269.647

# %%
MAE(eval_df["ArrivalTime1(µs)"],eval_df["ArrivalTime1_Manual"])
# Out:
# 5.109895334928228

# %%
MAE(eval_df["ArrivalTime2(µs)"],eval_df["ArrivalTime2_Manual"])
# Out:
# 4.41265789473684

# %%
MAE(eval_df["ArrivalTime3(µs)"],eval_df["ArrivalTime3_Manual"])
# Out:
# 5.4937846889952135

# %% [markdown]
# ## Visualization of the results

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=eval_df["ArrivalTime1(µs)"],
    y=eval_df["Depth"],
    mode="lines",
    name="Time 1 Automatic",
    line = dict(color='red', width=1)
))

fig.add_trace(go.Scatter(
    x=eval_df["ArrivalTime1_Manual"],
    y=eval_df["Depth"],
    mode="lines",
    name="Time 1 Manual",
    line = dict(color='red', width=1, dash="dot")
))

fig.add_trace(go.Scatter(
    x=eval_df["ArrivalTime2(µs)"],
    y=eval_df["Depth"],
    mode="lines",
    name="Time 2 Automatic",
    line = dict(color='green', width=1)
))

fig.add_trace(go.Scatter(
    x=eval_df["ArrivalTime2_Manual"],
    y=eval_df["Depth"],
    mode="lines",
    name="Time 2 Manual",
    line = dict(color='green', width=1, dash="dot")
))

fig.add_trace(go.Scatter(
    x=eval_df["ArrivalTime3(µs)"],
    y=eval_df["Depth"],
    mode="lines",
    name="Time 3 Automatic",
    line = dict(color='blue', width=1)
))

fig.add_trace(go.Scatter(
    x=eval_df["ArrivalTime3_Manual"],
    y=eval_df["Depth"],
    mode="lines",
    name="Time 3 Manual",
    line = dict(color='blue', width=1, dash="dot")
))

fig.update_layout(
    width=500,
    height=2500,
    margin=dict(l=20, r=20, t=20, b=20),
    yaxis = dict(autorange="reversed")
)

fig.update_xaxes(title="Arrival Time (µs)")
fig.update_yaxes(title="Depth (m)")

fig.show()
# Out:
# <div>                            <div id="85172d06-ddca-4216-b8f1-658daed37c9d" class="plotly-graph-div" style="height:2500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85172d06-ddca-4216-b8f1-658daed37c9d")) {                    Plotly.newPlot(                        "85172d06-ddca-4216-b8f1-658daed37c9d",                        [{"line": {"color": "red", "width": 1}, "mode": "lines", "name": "Time 1 Automatic", "type": "scatter", "x": [224, 224, 220, 228, 228, 228, 228, 228, 224, 224, 228, 228, 224, 224, 228, 232, 232, 228, 228, 228, 228, 228, 224, 228, 228, 276, 232, 228, 272, 224, 228, 228, 228, 236, 236, 236, 236, 232, 232, 232, 228, 228, 224, 224, 224, 224, 224, 224, 272, 224, 228, 224, 220, 220, 224, 228, 228, 228, 224, 272, 224, 224, 224, 224, 224, 228, 224, 224, 224, 220, 220, 216, 224, 224, 220, 240, 224, 220, 264, 272, 224, 228, 228, 236, 232, 232, 232, 232, 232, 228, 228, 232, 228, 228, 228, 224, 228, 224, 224, 228, 232, 228, 220, 220, 228, 228, 228, 228, 228, 276, 228, 228, 228, 224, 224, 228, 228, 228, 228, 228, 220, 220, 220, 220, 224, 224, 224, 224, 228, 228, 224, 228, 224, 232, 232, 232, 232, 228, 228, 228, 228, 228, 228, 228, 228, 224, 228, 228, 224, 228, 228, 228, 224, 224, 228, 232, 232, 228, 228, 224, 224, 228, 228, 228, 224, 228, 232, 228, 228, 228, 228, 220, 220, 220, 224, 220, 240, 228, 228, 268, 220, 224, 228, 236, 232, 228, 228, 232, 228, 228, 228, 228, 224, 224, 224, 224, 224, 224, 224, 272, 228, 228, 224, 220, 220, 228, 228, 224, 224, 224, 272, 224, 224, 224, 224, 224, 228, 228, 228, 228, 224, 220, 216, 220, 220, 220, 244, 224, 220, 260, 216, 224, 228, 228, 236, 228, 228, 228, 228, 228, 228, 228, 228, 228, 224, 224, 224, 224, 224, 272, 224, 228, 224, 220, 220, 228, 228, 228, 228, 228, 224, 224, 228, 228, 224, 224, 228, 228, 228, 228, 224, 220, 220, 220, 224, 220, 272, 224, 224, 220, 220, 224, 228, 228, 228, 232, 232, 232, 228, 228, 228, 228, 228, 224, 224, 224, 220, 224, 224, 224, 244, 228, 224, 216, 212, 220, 224, 224, 224, 228, 224, 228, 228, 232, 232, 228, 232, 232, 232, 232, 232, 232, 232, 232, 232, 232, 232, 228, 252, 256, 280, 240, 280, 288, 308, 316, 328, 328, 328, 324, 300, 304, 296, 296, 292, 292, 288, 284, 276, 264, 268, 268, 272, 272, 272, 272, 272, 344, 276, 280, 280, 284, 284, 288, 292, 292, 296, 300, 308, 312, 316, 324, 332, 336, 340, 344, 344, 340, 332, 328, 328, 328, 324, 320, 320, 320, 316, 312, 304, 300, 296, 292, 284, 276, 272, 268, 264, 264, 260, 260, 260, 260, 260, 264, 264, 268, 272, 272, 276, 284, 284, 292, 296, 300, 304, 308, 312, 316, 320, 308, 304, 304, 308, 308, 308, 308, 308, 308, 308, 312, 316, 316, 320, 324, 324, 328, 324, 320, 316, 316, 316, 316, 316, 316, 316, 316, 316, 312, 308, 308, 304, 304, 300, 300, 296, 292, 288, 284, 284, 280, 280, 276, 276, 276, 280, 280, 284, 288, 288, 292, 292, 292, 296, 300, 300, 304, 336, 336, 300, 304, 304, 304, 304, 304, 300, 296, 288, 284, 284, 284, 284, 284, 284, 284, 288, 276, 280, 284, 284, 284, 284, 280, 280, 276, 320, 360, 360, 356, 356, 296, 296, 296, 296, 300, 300, 300, 348, 348, 316, 316, 328, 328, 320, 316, 312, 308, 304, 304, 304, 304, 304, 308, 312, 312, 312, 312, 308, 304, 300, 352, 348, 284, 276, 280, 280, 280, 284, 284, 288, 288, 288, 288, 292, 296, 300, 304, 304, 308, 308, 308, 312, 312, 312, 312, 312, 308, 312, 316, 320, 320, 324, 324, 324, 328, 332, 336, 340, 340, 340, 336, 332, 332, 332, 336, 336, 332, 332, 332, 332, 332, 332, 332, 332, 332, 332, 332, 332, 332, 332, 332, 328, 328, 324, 320, 316, 316, 316, 312, 308, 300, 296, 288, 288, 284, 284, 280, 280, 280, 280, 276, 272, 272, 268, 268, 268, 268, 268, 272, 272, 272, 276, 280, 288, 288, 288, 288, 292, 292, 300, 304, 308, 312, 316, 320, 324, 324, 328, 332, 332, 332, 324, 324, 328, 324, 320, 316, 316, 316, 316, 320, 320, 320, 316, 384, 344, 344, 344, 344, 392, 428, 372, 368 ...
